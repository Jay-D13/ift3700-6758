# %% [markdown]
# <center><h1> IFT-6758  Data Science  </h1></center>
# <center><h2> Fall - 2020 </h2></center>
# <center><h3> Lab - 3</h3></center>
# <center><h3> </h3></center>
# <center><h3> Pandas</h3></center>

# %% [markdown]
# **pandas** is derived from the term "panel data", an econometrics term for data sets that include observations over multiple time periods for the same individuals.
# [[Source](https://www.dlr.de/sc/Portaldata/15/Resources/dokumente/pyhpc2011/submissions/pyhpc2011_submission_9.pdf) : *pandas: a Foundational Python Library for Data Analysis and Statistics" -  Wes McKinney*]

# %% [markdown]
# **pandas** has been built on top of the **numpy** package, enabling it to be used in conjunction with **scipy**, **matplotlib** and machine learning frameworks such as s**cikit-learn**.

# %% [markdown]
# ### Installation
# On Google colab `pandas` is already installed

# %%
# !pip install pandas

# %% [markdown]
# ### Import

# %% [markdown]
# The alias `pd` is a convention used by most people

# %%
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/Jhelum-Ch/DataScience_IFT6758/gh-pages/media/sales.csv
# Out:
# --2025-09-08 18:10:45--  https://raw.githubusercontent.com/Jhelum-Ch/DataScience_IFT6758/gh-pages/media/sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1037 (1.0K) [text/plain]
# Saving to: ‘sales.csv.2’
#
# sales.csv.2         100%[===================>]   1.01K  --.-KB/s    in 0s
#
# 2025-09-08 18:10:45 (49.8 MB/s) - ‘sales.csv.2’ saved [1037/1037]

# %% [markdown]
# ## [1] CREATE

# %% [markdown]
# ###(a) Create from file

# %% [markdown]
# Create a `DataFrame` by reading values from a CSV file.

# %%
df = pd.read_csv('sales.csv')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Jhelum-Ch/DataScience_IFT6758/gh-pages/media/sales.csv')
df
# Out:
#          Country Region Sales Person    Date of Purchase     Total  Quantity
# 0          India  North         John  12/25/2016 0:00:00    100000       567
# 1             US  North         Bill   1/20/2012 0:00:00    120000      3000
# 2             UK  North       Thomas   3/30/2011 0:00:00    140000       345
# 3      Australia   East         John   1/11/2014 0:00:00    160000      1000
# 4   South Africa   East         Bill    7/9/2010 0:00:00    180000       123
# 5      Singapore   East       Thomas   4/15/2015 0:00:00    200000      1000
# 6       Malaysia   West         John   9/26/2010 0:00:00   1000000      7890
# 7          India   West         Bill   9/29/2014 0:00:00    240000       200
# 8             US   West       Thomas   11/7/2011 0:00:00  26000000      1000
# 9             UK  North         John  11/10/2014 0:00:00    100000      1000
# 10     Australia  North         Bill    9/1/2015 0:00:00    120000       567
# ...

# %% [markdown]
# **Key Datatypes**
#
# `Series` -	1D labeled homogeneously-typed array
#
# `DataFrame`	- General 2D labeled, size-mutable tabular structure with potentially heterogeneously-typed column

# %% [markdown]
# ![https://bookdata.readthedocs.io/en/latest/_images/base_01_pandas_5_0.png](https://bookdata.readthedocs.io/en/latest/_images/base_01_pandas_5_0.png)
#
# [Source : https://bookdata.readthedocs.io]

# %% [markdown]
# Get the basic structural info of the `DataFrame`.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           20 non-null     object
#  1   Region            20 non-null     object
#  2   Sales Person      20 non-null     object
#  3   Date of Purchase  20 non-null     object
#  4   Total             20 non-null     int64
#  5   Quantity          20 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 1.1+ KB

# %% [markdown]
# Get the datatype of the data frame.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Get the datatype of each column of the `DataFrame`.

# %%
df.dtypes
# Out:
# Country             object
# Region              object
# Sales Person        object
# Date of Purchase    object
# Total                int64
# Quantity             int64
# dtype: object

# %% [markdown]
# Get the shape of the `DataFrame`.

# %%
df.shape
# Out:
# (20, 6)

# %% [markdown]
# Get the column names of the `DataFrame`.

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Sales Person', 'Date of Purchase', 'Total',
#        'Quantity'],
#       dtype='object')

# %% [markdown]
# Get the indices of the rows of the `DataFrame`.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %% [markdown]
# View the entire `DataFrame`.

# %%
df
# Out:
#          Country Region Sales Person    Date of Purchase     Total  Quantity
# 0          India  North         John  12/25/2016 0:00:00    100000       567
# 1             US  North         Bill   1/20/2012 0:00:00    120000      3000
# 2             UK  North       Thomas   3/30/2011 0:00:00    140000       345
# 3      Australia   East         John   1/11/2014 0:00:00    160000      1000
# 4   South Africa   East         Bill    7/9/2010 0:00:00    180000       123
# 5      Singapore   East       Thomas   4/15/2015 0:00:00    200000      1000
# 6       Malaysia   West         John   9/26/2010 0:00:00   1000000      7890
# 7          India   West         Bill   9/29/2014 0:00:00    240000       200
# 8             US   West       Thomas   11/7/2011 0:00:00  26000000      1000
# 9             UK  North         John  11/10/2014 0:00:00    100000      1000
# 10     Australia  North         Bill    9/1/2015 0:00:00    120000       567
# ...

# %% [markdown]
# Get the descriptive statistics of the `DataFrame`.

# %%
df.describe()
# Out:
#               Total     Quantity
# count  2.000000e+01    20.000000
# mean   1.502500e+06   977.900000
# std    5.769280e+06  1761.923497
# min    1.000000e+05    85.000000
# 25%    1.400000e+05    90.000000
# 50%    1.700000e+05   505.500000
# 75%    2.250000e+05  1000.000000
# max    2.600000e+07  7890.000000

# %% [markdown]
# Plot the histogram of a certain attribute (column) of the `DataFrame`.

# %%
df.hist('Quantity')
# Out:
# array([[<Axes: title={'center': 'Quantity'}>]], dtype=object)

# %% [markdown]
# ### (b) Create from data structures
#
# ![Source: https://pbpython.com](https://pbpython.com/images/pandas-dataframe-shadow.png)
#
#
# Source: https://pbpython.com

# %% [markdown]
# **Column oriented : Dictionary of lists**
#
# Data is a dict with column names as keys and the respective column values as list of values

# %%
cols_dict = {
    'city_name': ['San Francisco', 'San Jose', 'Sacramento'],
    'population': [852469, 1015785, 485199]
}

pd.DataFrame(cols_dict)
# Out:
#        city_name  population
# 0  San Francisco      852469
# 1       San Jose     1015785
# 2     Sacramento      485199

# %% [markdown]
# **Row oriented : List of dictionary items**
#
# Data is a list of dict items with column names as key and the respective cell value as value.

# %%
rows_dict = [{'city_name': 'San Francisco', 'population':852469},
             {'city_name': 'San Jose', 'population': 1015785},
             {'city_name': 'Sacramento', 'population': 485199}]

pd.DataFrame(rows_dict)
# Out:
#        city_name  population
# 0  San Francisco      852469
# 1       San Jose     1015785
# 2     Sacramento      485199

# %% [markdown]
# **Row oriented : List of tuple values**
#
# Data is a list with row values as a tuple and the column names specified as list.

# %%
rows_dict = [('San Francisco', 852469),
             ('San Jose', 1015785),
             ('Sacramento', 485199)]
labels = ['city_name', 'population']

#pd.DataFrame(rows_dict, columns=labels)

pd.DataFrame(rows_dict)
# Out:
#                0        1
# 0  San Francisco   852469
# 1       San Jose  1015785
# 2     Sacramento   485199

# %% [markdown]
# With different indices specified in `index`

# %%
pd.DataFrame(cols_dict, index=[104,108,111])
# Out:
#          city_name  population
# 104  San Francisco      852469
# 108       San Jose     1015785
# 111     Sacramento      485199

# %% [markdown]
# **Column oriented : Dictionary of Series**
#
# Data is a dict with column names as keys and the respective column values as `Series` of values.

# %%
city_names = pd.Series(['San Francisco', 'San Jose', 'Sacramento'])
populations = pd.Series([852469, 1015785, 485199])

pd.DataFrame({ 'city_name': city_names, 'population': populations })
# Out:
#        city_name  population
# 0  San Francisco      852469
# 1       San Jose     1015785
# 2     Sacramento      485199

# %% [markdown]
# **Saving `DataFrame` to local CSV file**

# %%
cities_df = pd.DataFrame({ 'city_name': city_names, 'population': populations })
cities_df.to_csv('cities.csv', index=None)

# %%
pd.read_csv('cities.csv')
# Out:
#        city_name  population
# 0  San Francisco      852469
# 1       San Jose     1015785
# 2     Sacramento      485199

# %% [markdown]
# ## [2] READ

# %%
df = pd.read_csv('sales.csv')

# %%
df.head()
# Out:
#         Country Region Sales Person    Date of Purchase   Total  Quantity
# 0         India  North         John  12/25/2016 0:00:00  100000       567
# 1            US  North         Bill   1/20/2012 0:00:00  120000      3000
# 2            UK  North       Thomas   3/30/2011 0:00:00  140000       345
# 3     Australia   East         John   1/11/2014 0:00:00  160000      1000
# 4  South Africa   East         Bill    7/9/2010 0:00:00  180000       123

# %%
df.tail()
# Out:
#          Country Region Sales Person    Date of Purchase   Total  Quantity
# 15            US   West         John    3/5/2012 0:00:00  220000        90
# 16            UK   West         Bill  10/24/2014 0:00:00  240000        90
# 17     Australia   West       Thomas  10/24/2012 0:00:00  260000        90
# 18  South Africa  North         John   10/1/2013 0:00:00  140000        85
# 19     Singapore  North         Bill   9/21/2012 0:00:00  150000        85

# %%
df.sample(5)
# Out:
#          Country Region Sales Person    Date of Purchase   Total  Quantity
# 1             US  North         Bill   1/20/2012 0:00:00  120000      3000
# 14         India   East       Thomas   4/15/2018 0:00:00  200000        90
# 4   South Africa   East         Bill    7/9/2010 0:00:00  180000       123
# 16            UK   West         Bill  10/24/2014 0:00:00  240000        90
# 12     Singapore   East         John    3/6/2018 0:00:00  160000       892

# %%
df['Sales Person']
# Out:
# 0       John
# 1       Bill
# 2     Thomas
# 3       John
# 4       Bill
# 5     Thomas
# 6       John
# 7       Bill
# 8     Thomas
# 9       John
# 10      Bill
# 11    Thomas
# 12      John
# 13      Bill
# 14    Thomas
# 15      John
# 16      Bill
# 17    Thomas
# 18      John
# 19      Bill
# Name: Sales Person, dtype: object

# %%
df.Country
# Out:
# 0            India
# 1               US
# 2               UK
# 3        Australia
# 4     South Africa
# 5        Singapore
# 6         Malaysia
# 7            India
# 8               US
# 9               UK
# 10       Australia
# 11    South Africa
# 12       Singapore
# 13        Malaysia
# 14           India
# 15              US
# 16              UK
# 17       Australia
# 18    South Africa
# 19       Singapore
# Name: Country, dtype: object

# %% [markdown]
# Get the datatype of a column.

# %%
type(df.Quantity)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Get the data type of the values of the column.

# %%
df.Quantity.dtypes
# Out:
# dtype('int64')

# %%
df[['Country','Quantity']]
# Out:
#          Country  Quantity
# 0          India       567
# 1             US      3000
# 2             UK       345
# 3      Australia      1000
# 4   South Africa       123
# 5      Singapore      1000
# 6       Malaysia      7890
# 7          India       200
# 8             US      1000
# 9             UK      1000
# 10     Australia       567
# 11  South Africa      1000
# 12     Singapore       892
# 13      Malaysia       444
# 14         India        90
# 15            US        90
# 16            UK        90
# 17     Australia        90
# 18  South Africa        85
# 19     Singapore        85

# %%
for row in df.columns:
  print(row)
# Out:
# Country
# Region
# Sales Person
# Date of Purchase
# Total
# Quantity

# %%
mask = df.Country=='UK'
mask
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# Name: Country, dtype: bool

# %%
df[df['Country']=='UK']
# Out:
#    Country Region Sales Person    Date of Purchase   Total  Quantity
# 2       UK  North       Thomas   3/30/2011 0:00:00  140000       345
# 9       UK  North         John  11/10/2014 0:00:00  100000      1000
# 16      UK   West         Bill  10/24/2014 0:00:00  240000        90

# %%
df[df.Quantity >= 1000]
# Out:
#          Country Region Sales Person    Date of Purchase     Total  Quantity
# 1             US  North         Bill   1/20/2012 0:00:00    120000      3000
# 3      Australia   East         John   1/11/2014 0:00:00    160000      1000
# 5      Singapore   East       Thomas   4/15/2015 0:00:00    200000      1000
# 6       Malaysia   West         John   9/26/2010 0:00:00   1000000      7890
# 8             US   West       Thomas   11/7/2011 0:00:00  26000000      1000
# 9             UK  North         John  11/10/2014 0:00:00    100000      1000
# 11  South Africa  North       Thomas  10/19/2016 0:00:00    140000      1000

# %%
df[df.Quantity >= 1000]['Country']
# Out:
# 1               US
# 3        Australia
# 5        Singapore
# 6         Malaysia
# 8               US
# 9               UK
# 11    South Africa
# Name: Country, dtype: object

# %%
df[df.Quantity >= 1000]['Country'].head()
# Out:
# 1           US
# 3    Australia
# 5    Singapore
# 6     Malaysia
# 8           US
# Name: Country, dtype: object

# %%
df['Country'][df.Quantity >= 1000]
# Out:
# 1               US
# 3        Australia
# 5        Singapore
# 6         Malaysia
# 8               US
# 9               UK
# 11    South Africa
# Name: Country, dtype: object

# %%
df[(df.Quantity >= 1000) & (df.Country=='US')]
# Out:
#   Country Region Sales Person   Date of Purchase     Total  Quantity
# 1      US  North         Bill  1/20/2012 0:00:00    120000      3000
# 8      US   West       Thomas  11/7/2011 0:00:00  26000000      1000

# %%
df.query(" Quantity>=1000  and Country=='US' ")
# Out:
#   Country Region Sales Person   Date of Purchase     Total  Quantity
# 1      US  North         Bill  1/20/2012 0:00:00    120000      3000
# 8      US   West       Thomas  11/7/2011 0:00:00  26000000      1000

# %%
df[df['Country'].isin(['UK','US','India'])]
# Out:
#    Country Region Sales Person    Date of Purchase     Total  Quantity
# 0    India  North         John  12/25/2016 0:00:00    100000       567
# 1       US  North         Bill   1/20/2012 0:00:00    120000      3000
# 2       UK  North       Thomas   3/30/2011 0:00:00    140000       345
# 7    India   West         Bill   9/29/2014 0:00:00    240000       200
# 8       US   West       Thomas   11/7/2011 0:00:00  26000000      1000
# 9       UK  North         John  11/10/2014 0:00:00    100000      1000
# 14   India   East       Thomas   4/15/2018 0:00:00    200000        90
# 15      US   West         John    3/5/2012 0:00:00    220000        90
# 16      UK   West         Bill  10/24/2014 0:00:00    240000        90

# %%
df.Country == "US"
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Country, dtype: bool

# %% [markdown]
# Boolean masked conditional queries

# %%
american = df.Country == "US"

heavy = df.Quantity > 1000

df[american & heavy]
# Out:
#   Country Region Sales Person   Date of Purchase   Total  Quantity
# 1      US  North         Bill  1/20/2012 0:00:00  120000      3000

# %% [markdown]
# DataFrame provides indexing label loc for selecting columns and rows by names to selects the specified columns and rows from the given DataFrame.
#
# `dataFrame.loc[<ROWS RANGE> , <COLUMNS RANGE>]`
#
# ROWS OR COLUMN RANGE can be also be ‘:’  and if given in rows or column Range parameter then the all entries will be included for corresponding row or column.

# %%
df.loc[:,'Country']
# Out:
# 0            India
# 1               US
# 2               UK
# 3        Australia
# 4     South Africa
# 5        Singapore
# 6         Malaysia
# 7            India
# 8               US
# 9               UK
# 10       Australia
# 11    South Africa
# 12       Singapore
# 13        Malaysia
# 14           India
# 15              US
# 16              UK
# 17       Australia
# 18    South Africa
# 19       Singapore
# Name: Country, dtype: object

# %%
df.loc[2:5,['Country','Quantity']]
# Out:
#         Country  Quantity
# 2            UK       345
# 3     Australia      1000
# 4  South Africa       123
# 5     Singapore      1000

# %%
df.loc[2:5, 'Sales Person':'Quantity']
# Out:
#   Sales Person   Date of Purchase   Total  Quantity
# 2       Thomas  3/30/2011 0:00:00  140000       345
# 3         John  1/11/2014 0:00:00  160000      1000
# 4         Bill   7/9/2010 0:00:00  180000       123
# 5       Thomas  4/15/2015 0:00:00  200000      1000

# %%
df.loc[11::2]
# Out:
#          Country Region Sales Person    Date of Purchase   Total  Quantity
# 11  South Africa  North       Thomas  10/19/2016 0:00:00  140000      1000
# 13      Malaysia   East         Bill   10/3/2014 0:00:00  180000       444
# 15            US   West         John    3/5/2012 0:00:00  220000        90
# 17     Australia   West       Thomas  10/24/2012 0:00:00  260000        90
# 19     Singapore  North         Bill   9/21/2012 0:00:00  150000        85

# %%
df.loc[11,:]
# Out:
# Country                   South Africa
# Region                           North
# Sales Person                    Thomas
# Date of Purchase    10/19/2016 0:00:00
# Total                           140000
# Quantity                          1000
# Name: 11, dtype: object

# %%
df.loc[[11,17],:]
# Out:
#          Country Region Sales Person    Date of Purchase   Total  Quantity
# 11  South Africa  North       Thomas  10/19/2016 0:00:00  140000      1000
# 17     Australia   West       Thomas  10/24/2012 0:00:00  260000        90

# %% [markdown]
# `DataFrame` provides indexing label `iloc` for accessing the column and rows by index positions to select the columns and rows from DataFrame by index position specified in range.
#
# `dataFrame.iloc[<ROWS INDEX RANGE> , <COLUMNS INDEX RANGE>]`
#
# If ‘:’ is given in rows or column Index Range then all entries will be included for corresponding row or column.

# %%
df.iloc[0]
# Out:
# Country                          India
# Region                           North
# Sales Person                      John
# Date of Purchase    12/25/2016 0:00:00
# Total                           100000
# Quantity                           567
# Name: 0, dtype: object

# %%
df.iloc[0,0]
# Out:
# 'India'

# %%
df.iloc[::2,::2]
# Out:
#          Country Sales Person     Total
# 0          India         John    100000
# 2             UK       Thomas    140000
# 4   South Africa         Bill    180000
# 6       Malaysia         John   1000000
# 8             US       Thomas  26000000
# 10     Australia         Bill    120000
# 12     Singapore         John    160000
# 14         India       Thomas    200000
# 16            UK         Bill    240000
# 18  South Africa         John    140000

# %%
df.iloc[[11,13,17],[2,5]]
# Out:
#    Sales Person  Quantity
# 11       Thomas      1000
# 13         Bill       444
# 17       Thomas        90

# %% [markdown]
# ## [3] UPDATE

# %% [markdown]
# Appending to a DataFrame

# %%
# new_df = pd.DataFrame([{'Country':'Singapore', 'Region':'North'	, 'Sales Person':'Bill'	, 'Date of Purchase':'9/21/2012 0:00:00'	, 'Total':'150000' ,	'Quantity':85}])
new_row = df.iloc[-1,:]
new_df = pd.concat([df, new_row.to_frame().T], ignore_index=True) # New copy
new_df
# Out:
#          Country Region Sales Person    Date of Purchase     Total Quantity
# 0          India  North         John  12/25/2016 0:00:00    100000      567
# 1             US  North         Bill   1/20/2012 0:00:00    120000     3000
# 2             UK  North       Thomas   3/30/2011 0:00:00    140000      345
# 3      Australia   East         John   1/11/2014 0:00:00    160000     1000
# 4   South Africa   East         Bill    7/9/2010 0:00:00    180000      123
# 5      Singapore   East       Thomas   4/15/2015 0:00:00    200000     1000
# 6       Malaysia   West         John   9/26/2010 0:00:00   1000000     7890
# 7          India   West         Bill   9/29/2014 0:00:00    240000      200
# 8             US   West       Thomas   11/7/2011 0:00:00  26000000     1000
# 9             UK  North         John  11/10/2014 0:00:00    100000     1000
# 10     Australia  North         Bill    9/1/2015 0:00:00    120000      567
# ...

# %%
new_df.shape
# Out:
# (21, 6)

# %%
df.shape
# Out:
# (20, 6)

# %%
new_df
# Out:
#          Country Region Sales Person    Date of Purchase     Total Quantity
# 0          India  North         John  12/25/2016 0:00:00    100000      567
# 1             US  North         Bill   1/20/2012 0:00:00    120000     3000
# 2             UK  North       Thomas   3/30/2011 0:00:00    140000      345
# 3      Australia   East         John   1/11/2014 0:00:00    160000     1000
# 4   South Africa   East         Bill    7/9/2010 0:00:00    180000      123
# 5      Singapore   East       Thomas   4/15/2015 0:00:00    200000     1000
# 6       Malaysia   West         John   9/26/2010 0:00:00   1000000     7890
# 7          India   West         Bill   9/29/2014 0:00:00    240000      200
# 8             US   West       Thomas   11/7/2011 0:00:00  26000000     1000
# 9             UK  North         John  11/10/2014 0:00:00    100000     1000
# 10     Australia  North         Bill    9/1/2015 0:00:00    120000      567
# ...

# %%
new_df.iloc[20,:]
# Out:
# Country                     Singapore
# Region                          North
# Sales Person                     Bill
# Date of Purchase    9/21/2012 0:00:00
# Total                          150000
# Quantity                           85
# Name: 20, dtype: object

# %%
new_df.drop_duplicates()   #inplace=True, keep=False
# Out:
#          Country Region Sales Person    Date of Purchase     Total Quantity
# 0          India  North         John  12/25/2016 0:00:00    100000      567
# 1             US  North         Bill   1/20/2012 0:00:00    120000     3000
# 2             UK  North       Thomas   3/30/2011 0:00:00    140000      345
# 3      Australia   East         John   1/11/2014 0:00:00    160000     1000
# 4   South Africa   East         Bill    7/9/2010 0:00:00    180000      123
# 5      Singapore   East       Thomas   4/15/2015 0:00:00    200000     1000
# 6       Malaysia   West         John   9/26/2010 0:00:00   1000000     7890
# 7          India   West         Bill   9/29/2014 0:00:00    240000      200
# 8             US   West       Thomas   11/7/2011 0:00:00  26000000     1000
# 9             UK  North         John  11/10/2014 0:00:00    100000     1000
# 10     Australia  North         Bill    9/1/2015 0:00:00    120000      567
# ...

# %% [markdown]
# Array of zeros

# %%
new_df.shape
# Out:
# (21, 6)

# %% [markdown]
# Rename columns

# %%
new_df.columns = ['country','region','person','date','total','quantity']
# new_df.columns = [col.lower() for col in new_df.columns]
new_df.tail()
# Out:
#          country region  person                date   total quantity
# 16            UK   West    Bill  10/24/2014 0:00:00  240000       90
# 17     Australia   West  Thomas  10/24/2012 0:00:00  260000       90
# 18  South Africa  North    John   10/1/2013 0:00:00  140000       85
# 19     Singapore  North    Bill   9/21/2012 0:00:00  150000       85
# 20     Singapore  North    Bill   9/21/2012 0:00:00  150000       85

# %% [markdown]
# Alternatively use `rename` function.

# %%
new_df.rename(columns={
        'region': 'zone',
        'quantity': 'qty'
    }, inplace=True)


new_df.columns
# Out:
# Index(['country', 'zone', 'person', 'date', 'total', 'qty'], dtype='object')

# %% [markdown]
# Array from a range of integers

# %%
new_df.loc[11::2,'qty'] *= 100

new_df
# Out:
#          country   zone  person                date     total     qty
# 0          India  North    John  12/25/2016 0:00:00    100000     567
# 1             US  North    Bill   1/20/2012 0:00:00    120000    3000
# 2             UK  North  Thomas   3/30/2011 0:00:00    140000     345
# 3      Australia   East    John   1/11/2014 0:00:00    160000    1000
# 4   South Africa   East    Bill    7/9/2010 0:00:00    180000     123
# 5      Singapore   East  Thomas   4/15/2015 0:00:00    200000    1000
# 6       Malaysia   West    John   9/26/2010 0:00:00   1000000    7890
# 7          India   West    Bill   9/29/2014 0:00:00    240000     200
# 8             US   West  Thomas   11/7/2011 0:00:00  26000000    1000
# 9             UK  North    John  11/10/2014 0:00:00    100000    1000
# 10     Australia  North    Bill    9/1/2015 0:00:00    120000     567
# 11  South Africa  North  Thomas  10/19/2016 0:00:00    140000  100000
# ...

# %% [markdown]
# ## [4] DELETE

# %% [markdown]
# More details : https://note.nkmk.me/en/python-pandas-drop/

# %%
new_df
# Out:
#          country   zone  person                date     total     qty
# 0          India  North    John  12/25/2016 0:00:00    100000     567
# 1             US  North    Bill   1/20/2012 0:00:00    120000    3000
# 2             UK  North  Thomas   3/30/2011 0:00:00    140000     345
# 3      Australia   East    John   1/11/2014 0:00:00    160000    1000
# 4   South Africa   East    Bill    7/9/2010 0:00:00    180000     123
# 5      Singapore   East  Thomas   4/15/2015 0:00:00    200000    1000
# 6       Malaysia   West    John   9/26/2010 0:00:00   1000000    7890
# 7          India   West    Bill   9/29/2014 0:00:00    240000     200
# 8             US   West  Thomas   11/7/2011 0:00:00  26000000    1000
# 9             UK  North    John  11/10/2014 0:00:00    100000    1000
# 10     Australia  North    Bill    9/1/2015 0:00:00    120000     567
# 11  South Africa  North  Thomas  10/19/2016 0:00:00    140000  100000
# ...

# %% [markdown]
# Delete a column in the view using drop()

# %%
new_df.drop(columns='date')
#inplace=?
# add multiple cols
# Out:
#          country   zone  person     total     qty
# 0          India  North    John    100000     567
# 1             US  North    Bill    120000    3000
# 2             UK  North  Thomas    140000     345
# 3      Australia   East    John    160000    1000
# 4   South Africa   East    Bill    180000     123
# 5      Singapore   East  Thomas    200000    1000
# 6       Malaysia   West    John   1000000    7890
# 7          India   West    Bill    240000     200
# 8             US   West  Thomas  26000000    1000
# 9             UK  North    John    100000    1000
# 10     Australia  North    Bill    120000     567
# 11  South Africa  North  Thomas    140000  100000
# 12     Singapore   East    John    160000     892
# 13      Malaysia   East    Bill    180000   44400
# 14         India   East  Thomas    200000      90
# 15            US   West    John    220000    9000
# 16            UK   West    Bill    240000      90
# 17     Australia   West  Thomas    260000    9000
# ...

# %% [markdown]
# Remark that the contents of DataFrame

# %%
new_df
# Out:
#          country   zone  person                date     total     qty
# 0          India  North    John  12/25/2016 0:00:00    100000     567
# 1             US  North    Bill   1/20/2012 0:00:00    120000    3000
# 2             UK  North  Thomas   3/30/2011 0:00:00    140000     345
# 3      Australia   East    John   1/11/2014 0:00:00    160000    1000
# 4   South Africa   East    Bill    7/9/2010 0:00:00    180000     123
# 5      Singapore   East  Thomas   4/15/2015 0:00:00    200000    1000
# 6       Malaysia   West    John   9/26/2010 0:00:00   1000000    7890
# 7          India   West    Bill   9/29/2014 0:00:00    240000     200
# 8             US   West  Thomas   11/7/2011 0:00:00  26000000    1000
# 9             UK  North    John  11/10/2014 0:00:00    100000    1000
# 10     Australia  North    Bill    9/1/2015 0:00:00    120000     567
# 11  South Africa  North  Thomas  10/19/2016 0:00:00    140000  100000
# ...

# %% [markdown]
# Delete row using drop(index)

# %%
new_df.drop(index=0)
#new_df.drop(index=[0,1,5])
# Out:
#          country   zone  person                date     total     qty
# 1             US  North    Bill   1/20/2012 0:00:00    120000    3000
# 2             UK  North  Thomas   3/30/2011 0:00:00    140000     345
# 3      Australia   East    John   1/11/2014 0:00:00    160000    1000
# 4   South Africa   East    Bill    7/9/2010 0:00:00    180000     123
# 5      Singapore   East  Thomas   4/15/2015 0:00:00    200000    1000
# 6       Malaysia   West    John   9/26/2010 0:00:00   1000000    7890
# 7          India   West    Bill   9/29/2014 0:00:00    240000     200
# 8             US   West  Thomas   11/7/2011 0:00:00  26000000    1000
# 9             UK  North    John  11/10/2014 0:00:00    100000    1000
# 10     Australia  North    Bill    9/1/2015 0:00:00    120000     567
# 11  South Africa  North  Thomas  10/19/2016 0:00:00    140000  100000
# 12     Singapore   East    John    3/6/2018 0:00:00    160000     892
# ...

# %%
new_df.drop(index=[0,1,5])
# Out:
#          country   zone  person                date     total     qty
# 2             UK  North  Thomas   3/30/2011 0:00:00    140000     345
# 3      Australia   East    John   1/11/2014 0:00:00    160000    1000
# 4   South Africa   East    Bill    7/9/2010 0:00:00    180000     123
# 6       Malaysia   West    John   9/26/2010 0:00:00   1000000    7890
# 7          India   West    Bill   9/29/2014 0:00:00    240000     200
# 8             US   West  Thomas   11/7/2011 0:00:00  26000000    1000
# 9             UK  North    John  11/10/2014 0:00:00    100000    1000
# 10     Australia  North    Bill    9/1/2015 0:00:00    120000     567
# 11  South Africa  North  Thomas  10/19/2016 0:00:00    140000  100000
# 12     Singapore   East    John    3/6/2018 0:00:00    160000     892
# 13      Malaysia   East    Bill   10/3/2014 0:00:00    180000   44400
# 14         India   East  Thomas   4/15/2018 0:00:00    200000      90
# ...

# %% [markdown]
# ##[5] AGGREGATE FUNCTIONS

# %% [markdown]
# Count of a DataFrame

# %%
df.count()
# Out:
# Country             20
# Region              20
# Sales Person        20
# Date of Purchase    20
# Total               20
# Quantity            20
# dtype: int64

# %% [markdown]
# Count of a column

# %%
df.Country.count()
# Out:
# np.int64(20)

# %%
df.Country.unique()
# Out:
# array(['India', 'US', 'UK', 'Australia', 'South Africa', 'Singapore',
#        'Malaysia'], dtype=object)

# %%
df[df.Country != 'UK'].Total.sum()
# Out:
# np.int64(29570000)

# %%
df.Quantity.median()
# Out:
# 505.5

# %% [markdown]
# Groupby

# %%
for group in df.groupby('Country'):
  print(group)
  print("\n--------------------\n")
# Out:
# ('Australia',       Country Region Sales Person    Date of Purchase   Total  Quantity
# 3   Australia   East         John   1/11/2014 0:00:00  160000      1000
# 10  Australia  North         Bill    9/1/2015 0:00:00  120000       567
# 17  Australia   West       Thomas  10/24/2012 0:00:00  260000        90)
#
# --------------------
#
# ('India',    Country Region Sales Person    Date of Purchase   Total  Quantity
# 0    India  North         John  12/25/2016 0:00:00  100000       567
# 7    India   West         Bill   9/29/2014 0:00:00  240000       200
# 14   India   East       Thomas   4/15/2018 0:00:00  200000        90)
#
# --------------------
#
# ('Malaysia',      Country Region Sales Person   Date of Purchase    Total  Quantity
# 6   Malaysia   West         John  9/26/2010 0:00:00  1000000      7890
# 13  Malaysia   East         Bill  10/3/2014 0:00:00   180000       444)
#
# --------------------
#
# ...

# %%
df.groupby('Country')[['Total', 'Quantity']].mean()[['Quantity']]
# Out:
#                  Quantity
# Country
# Australia      552.333333
# India          285.666667
# Malaysia      4167.000000
# Singapore      659.000000
# South Africa   402.666667
# UK             478.333333
# US            1363.333333

# %% [markdown]
# # [6] MISC

# %% [markdown]
# apply() to single column

# %%
def convert_total(total,factor=1000):
  return total/factor

#new_df['total'] =
new_df.total.apply(convert_total)
# Out:
# 0       100.0
# 1       120.0
# 2       140.0
# 3       160.0
# 4       180.0
# 5       200.0
# 6      1000.0
# 7       240.0
# 8     26000.0
# 9       100.0
# 10      120.0
# 11      140.0
# 12      160.0
# 13      180.0
# 14      200.0
# 15      220.0
# 16      240.0
# 17      260.0
# 18      140.0
# 19      150.0
# 20      150.0
# Name: total, dtype: float64

# %%
# Manipulate all entries in date column using lambda

new_df.date = new_df.date.apply(lambda x: x.split()[0])
# Note : x here refers to each entry in the column series ('date')

# %% [markdown]
# apply() to all columns

# %%
num_df = new_df[['total','qty']]
str_df = new_df[['country','zone','person']]

num_df.apply(lambda x : x * 20)
# Note x here refers to each column series
# Out:
#         total      qty
# 0     2000000    11340
# 1     2400000    60000
# 2     2800000     6900
# 3     3200000    20000
# 4     3600000     2460
# 5     4000000    20000
# 6    20000000   157800
# 7     4800000     4000
# 8   520000000    20000
# 9     2000000    20000
# 10    2400000    11340
# 11    2800000  2000000
# 12    3200000    17840
# 13    3600000   888000
# 14    4000000     1800
# 15    4400000   180000
# 16    4800000     1800
# 17    5200000   180000
# 18    2800000     1700
# 19    3000000   170000
# 20    3000000     1700

# %% [markdown]
# apply() to each row

# %%
def qty_percentage(row):
  return row['qty'] * 100 / row['total']

#new_df['qty_pc'] =
new_df.apply(qty_percentage, axis=1)
# Out:
# 0      0.567000
# 1      2.500000
# 2      0.246429
# 3      0.625000
# 4      0.068333
# 5      0.500000
# 6      0.789000
# 7      0.083333
# 8      0.003846
# 9      1.000000
# 10     0.472500
# 11    71.428571
# 12     0.557500
# 13    24.666667
# 14     0.045000
# 15     4.090909
# 16     0.037500
# 17     3.461538
# 18     0.060714
# 19     5.666667
# 20     0.056667
# dtype: float64

# %% [markdown]
# Plot functions

# %%
new_df.qty.plot(kind='box');

# %%
new_df.plot(kind='scatter', x='qty', y='total', title='Qty vs Total');

# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### 1. Try to load the file in the path `sample_data/california_housing_train.csv` into a `DataFrame` and do basic data exploration to understand the key details about the data.

# %%
df = pd.read_csv("sample_data/california_housing_train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# Determine whether there are any NaNs in this dataframe

# %%
df.isnull().any().any()
# Out:
# np.False_

# %% [markdown]
# Find the total population of the dataframe

# %%
df['population'].sum()
# Out:
# np.float64(24302757.0)

# %% [markdown]
# Return a dataframe with `*n*` elements randomly sampled from the dataframe

# %%
n = 10
df.sample(n)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11621    -121.29     38.67                20.0       1992.0           363.0
# 14841    -122.21     37.43                23.0       5741.0          1012.0
# 11022    -120.95     37.60                35.0       1493.0           278.0
# 6565     -118.28     34.09                38.0        790.0           275.0
# 7504     -118.36     34.04                49.0        995.0           184.0
# 12439    -121.59     39.79                20.0        743.0           171.0
# 6947     -118.31     34.05                42.0        443.0           223.0
# 12251    -121.48     38.58                48.0       2434.0           744.0
# 3171     -117.84     33.79                37.0       2733.0           460.0
# 4087     -117.98     34.04                34.0       2547.0           537.0
#
#        population  households  median_income  median_house_value
# 11621       889.0       346.0         3.6516            130500.0
# ...

# %% [markdown]
# Select the rows where the `housing_median_age` is under 18 and the `median_house_value` is over 300,000

# %%
df.loc[(df['housing_median_age'] < 18) & (df['median_house_value'] > 300000)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 172      -116.26     33.65                 3.0       7437.0          1222.0
# 187      -116.33     33.72                11.0      12327.0          2000.0
# 193      -116.37     33.69                 7.0       8806.0          1542.0
# 210      -116.42     33.76                14.0      16921.0          2837.0
# 220      -116.44     33.74                 5.0        846.0           249.0
# ...          ...       ...                 ...          ...             ...
# 16520    -122.65     38.37                15.0       1848.0           280.0
# 16598    -122.71     38.50                15.0       5645.0           830.0
# 16672    -122.78     38.44                14.0       4143.0           656.0
# 16715    -122.85     38.37                16.0       1762.0           293.0
# 16776    -123.00     38.33                 8.0       3223.0           637.0
#
# ...

# %% [markdown]
# #### 2. Let's use the sales data:

# %%
df = pd.read_csv('sales.csv')

# %% [markdown]
# Programatically find the number of unique countries in this dataset

# %%
len(df['Country'].unique())
# Out:
# 7

# %% [markdown]
# Sort the df first by the values in the 'Country' column in ascending order, then by the value in the 'Sales Person' column in ascending order

# %%
df.sort_values(by=['Country', 'Sales Person'], ascending=[True, True])
# Out:
#          Country Region Sales Person    Date of Purchase     Total  Quantity
# 10     Australia  North         Bill    9/1/2015 0:00:00    120000       567
# 3      Australia   East         John   1/11/2014 0:00:00    160000      1000
# 17     Australia   West       Thomas  10/24/2012 0:00:00    260000        90
# 7          India   West         Bill   9/29/2014 0:00:00    240000       200
# 0          India  North         John  12/25/2016 0:00:00    100000       567
# 14         India   East       Thomas   4/15/2018 0:00:00    200000        90
# 13      Malaysia   East         Bill   10/3/2014 0:00:00    180000       444
# 6       Malaysia   West         John   9/26/2010 0:00:00   1000000      7890
# 19     Singapore  North         Bill   9/21/2012 0:00:00    150000        85
# 12     Singapore   East         John    3/6/2018 0:00:00    160000       892
# 5      Singapore   East       Thomas   4/15/2015 0:00:00    200000      1000
# ...

# %% [markdown]
# #### 3. Given a DataFrame of random numeric values:

# %%
import numpy as np
df = pd.DataFrame(np.random.random(size=(5, 3)))

# %% [markdown]
# How do you subtract the row mean from each element in the row?

# %%
df.sub(df.mean(axis=1), axis=0)
# Out:
#           0         1         2
# 0  0.021880 -0.129691  0.107811
# 1  0.270439 -0.268028 -0.002411
# 2 -0.102504  0.351113 -0.248609
# 3 -0.031615  0.325121 -0.293506
# 4  0.397336 -0.260097 -0.137238

# %% [markdown]
# #### 4. How do you count how many unique rows a DataFrame has (i.e. ignore all rows that are duplicates)?

# %%
# Given this dataframe
df = pd.DataFrame(np.random.randint(0, 2, size=(10, 3)))

len(df.drop_duplicates(keep=False))
# Out:
# 4

# %% [markdown]
# #### 5. Cleaning a DataFrame

# %%
import numpy as np
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm',
                               'Budapest_PaRis', 'Brussels_londOn'],
              'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
              'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
                   'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
                               '12. Air France', '"Swiss Air"']})

# %% [markdown]
# Some values in the the **FlightNumber** column are missing (they are `NaN`). These numbers are meant to increase by 10 with each row so 10055 and 10075 need to be put in place. Modify `df` to fill in these missing numbers and make the column an integer column (instead of a float column).

# %%
df['FlightNumber'] = df['FlightNumber'].interpolate().astype(int)

# %% [markdown]
# The **From\_To** column would be better as two separate columns! Split each string on the underscore delimiter `_` to give a new temporary DataFrame called 'temp' with the correct values. Assign the correct column names 'From' and 'To' to this temporary DataFrame.

# %%
temp = df.From_To.str.split('_', expand=True)
temp.columns = ['From', 'To']
temp
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %% [markdown]
# Notice how the capitalisation of the city names is all mixed up in this temporary DataFrame 'temp'. Standardise the strings so that only the first letter is uppercase (e.g. "londON" should become "London".)

# %%
temp['From'] = temp['From'].str.capitalize()
temp['To'] = temp['To'].str.capitalize()
temp
# Out:
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %% [markdown]
# Delete the From_To column from **41.** Delete the **From_To** column from `df` and attach the temporary DataFrame 'temp' from the previous questions.`df` and attach the temporary DataFrame from the previous questions.

# %%
df = df.drop('From_To', axis=1)
df = df.join(temp)
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    London      Paris
# 1         10055            []    <Air France> (12)    Madrid      Milan
# 2         10065  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075          [13]       12. Air France  Budapest      Paris
# 4         10085      [67, 32]          "Swiss Air"  Brussels     London

# %% [markdown]
# #### 6. Look at last weeks notebook [here](https://colab.research.google.com/drive/1w77xXy6TxaV2yo8rEzvHjuM4NzGMgTfL#scrollTo=faxVdJ0l1sRk) and look at the section 6 under Seaborn. Load the penguins dataset as you see there.
#
# a. How many penguins have no gender assigned?
#
# b. Clean the data as you see fit without deleting any rows.
#
# c. Visualize the data in a plot of your choice and guess the possible gender of the penguins with no gender assigned.

# %%
# This is a teaser for the Homework-1. Keep trying this!

# %% [markdown]
# ### REFERENCES
#
# 1.   Datacamp Pandas [cheatsheet](https://www.dataquest.io/blog/pandas-cheat-sheet/)
# 2.   Morphcode [cheatsheet](https://morphocode.com/pandas-cheat-sheet/)
# 3.  U Idaho [reference](https://www.webpages.uidaho.edu/~stevel/504/Pandas%20DataFrame%20Notes.pdf)
# 4. Pandas Puzzles [reference](https://github.com/ajcr/100-pandas-puzzles)
